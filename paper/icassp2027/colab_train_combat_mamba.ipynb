# %% [markdown]
# # Mamba-COP-RL: Combat Environment Training
#
# **Paper**: *When Does Temporal Memory Help? SSM vs MLP in RL-Based Track Management*
#
# - `obs_dim = 183` (raw COP spatial spectrum 181D + 2 global features)
# - `n_scans = 200` (long episodes)
# - 4 combat scenarios: Jamming / Stealth / Saturation / Formation
# - Compares: Fixed threshold vs MLP-PPO vs Mamba-COP-RL

# %%
# ── Cell 1: Clone & Install ───────────────────────────────
# !git clone https://github.com/DrJinHoChoi/IronDome-DOA-Tracking.git
# %cd IronDome-DOA-Tracking
# !pip install torch scipy matplotlib -q

# %%
# ── Cell 2: Train ─────────────────────────────────────────
# !python experiments/train_combat_mamba.py

# %%
# ── Cell 3: Result Figure ─────────────────────────────────
from IPython.display import Image
Image('results/figures/fig_combat_mamba.png')

# %%
# ── Cell 4: Download results ──────────────────────────────
from google.colab import files
import os

# Download figure
files.download('results/figures/fig_combat_mamba.png')

# Download trained model
files.download('results/mamba_combat_best.pt')
